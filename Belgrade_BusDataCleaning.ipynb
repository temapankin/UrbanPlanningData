# %% [markdown]
# This code entails data filtering and cleaning that was used to create data for the [Trasnmetrika](https://transmetrika.com/) Belgrade public transit data challenge.

# %%
import pandas as pd
import partridge as ptg
import geopandas
import numpy as np
from datetime import datetime

# %%
colnames = ["id", 'stop_id', 'route_path_id', 
            'forecast_time', 'byTelemetry', 'tmId', 'routePathId', 'request_time']

# %%
tab = pd.read_csv("forecast.csv", names = colnames, header=None)

# %%
tab = tab.reset_index(drop=True)

# %%
tab
# Out:
#               id                               stop_id  \
# 0              1  0733a07f-cd14-4fc9-81fe-746951f62fdf
# 1              2  0733a07f-cd14-4fc9-81fe-746951f62fdf
# 2              3  0004b6de-c70f-4ae7-adf6-0aa4f563d782
# 3              4  0004b6de-c70f-4ae7-adf6-0aa4f563d782
# 4              5  0004b6de-c70f-4ae7-adf6-0aa4f563d782
# ...          ...                                   ...
# 3479532  3486344  f2ea70b3-6545-4aab-b8fd-788462c2e9a8
# 3479533  3486345  93562e3f-873f-4d09-8264-b735d2ff83a4
# 3479534  3486346  93562e3f-873f-4d09-8264-b735d2ff83a4
# 3479535  3486347  93562e3f-873f-4d09-8264-b735d2ff83a4
# 3479536  3486348  93562e3f-873f-4d09-8264-b735d2ff83a4
#
#                                 route_path_id  forecast_time  byTelemetry  \
# 0        6e223245-fb0c-4a3e-b843-64d894c07592     1644633597            0
# 1        79be2042-7c61-4208-89ce-0ef12f417fbd     1644642657            0
# 2        74e301c2-e932-4965-b72d-4d03697dd405     1644633537            0
# 3        4839019b-d276-4b8a-a1b1-860d70703f93     1644633717            0
# 4        2d178ae9-e4c2-4562-b20a-a3b46d4f5cd8     1644635697            0
# ...                                       ...            ...          ...
# 3479532  bceeb5a3-d4d4-4ad7-b3df-6837942c7c2d     1645115681            0
# 3479533  dfc7849d-96c0-4345-af14-3ac6a2ff6b84     1645115561            0
# 3479534  aa12db25-c5fd-4a26-8d06-6c185f8ba771     1645115621            0
# 3479535  ceb2caaa-75d9-4b6b-bd01-5cbc9a4572e3     1645129601            0
# 3479536  103056a3-86fe-4c73-9651-03bf58b53022     1645179701            0
#
#          tmId                           routePathId  request_time
# 0           0  7e8c4dab-5015-4f71-aed0-09e6f0012d73    1644620502
# 1           0  2d0ac2d3-bb64-46bb-8dd6-196d9195cb47    1644620502
# 2           0  59dc26dd-2dfe-4e3d-8f5f-d7c1a9e8f200    1644620502
# 3           0  91529f82-1311-4605-9161-155434d0140b    1644620502
# 4           0  f4ad4d26-e458-4549-b61b-928473300698    1644620502
# ...       ...                                   ...           ...
# 3479532     0  c02f42b4-dd1f-4b7e-8bd7-5d17e15b6a39    1645111705
# 3479533     0  84e59fdd-d31f-4ffe-b04e-71791aae463e    1645111705
# 3479534     0  9a4140d9-8e67-4d86-b852-4fa95183a4cf    1645111705
# 3479535     0  748671c9-256e-42bd-be54-e25e76dfd76c    1645111705
# 3479536     0  777d3f16-c6ac-4d66-858f-061063fef378    1645111705
#
# [3479537 rows x 8 columns]

# %%
import numpy as np
import pandas as pd
from time import time, asctime


def get_cleaned(read_from=None, write_to=None):
    
    df = pd.read_csv(read_from,sep=';', header=0)
    

    start = time()
    print(f'\nCleaner started at: {asctime()}')

    df = df[df['byTelemetry'] == 1]
    data_cleaned = np.array(df.columns)
    i = 0

    for stop in df['stop_id'].unique():
        for route in df[df['stop_id'] == stop]['routePathId'].unique():
            for bus in df[(df['stop_id'] == stop) &
                          (df['routePathId'] == route)]['tmId'].unique():
                dups = df[
                    (df['stop_id'] == stop) &
                    (df['routePathId'] == route) &
                    (df['tmId'] == bus)].sort_values('request_time', ascending=False)

                data_cleaned = np.vstack((data_cleaned, dups.to_numpy()[0, :]))

                for idx, dup in dups.iloc[1:, :].iterrows():
                    if abs(dup['forecast_time'] - float(data_cleaned[-1, 3])) > 1200:
                        data_cleaned = np.vstack((data_cleaned, dup.to_numpy()))
                    i += 1
                    if i % 1000 == 0:
                        elapsed = (time() - start) / 60
                        print(f'{i:,} items handled, {elapsed:.2f} min elapsed,')

    df_cleaned = pd.DataFrame(data_cleaned[1:], columns=data_cleaned[0])
    df_cleaned.drop_duplicates(inplace=True)

    elapsed = (time() - start) / 60
    print(f'Cleaner finished at: {asctime()}\n{elapsed:.2f} min elapsed.')

    df.to_csv(write_to, index=False)

# %%
get_cleaned(read_from = "forecast_new_new.csv",
            write_to = "forecast_final.csv")
# Out:
# Cleaner started at: Sun Dec  4 20:35:35 2022
# 1,000 items handled, 0.18 min elapsed,
# 2,000 items handled, 0.27 min elapsed,
# 3,000 items handled, 0.39 min elapsed,
# 4,000 items handled, 0.52 min elapsed,
# 5,000 items handled, 0.61 min elapsed,
# 6,000 items handled, 0.74 min elapsed,
# 7,000 items handled, 0.85 min elapsed,
# 8,000 items handled, 0.98 min elapsed,
# 9,000 items handled, 1.09 min elapsed,
# 10,000 items handled, 1.26 min elapsed,
# 11,000 items handled, 1.42 min elapsed,
# 12,000 items handled, 1.53 min elapsed,
# 13,000 items handled, 1.71 min elapsed,
# 14,000 items handled, 1.84 min elapsed,
# 15,000 items handled, 1.97 min elapsed,
# 16,000 items handled, 2.08 min elapsed,
# 17,000 items handled, 2.18 min elapsed,
# 18,000 items handled, 2.29 min elapsed,
# 19,000 items handled, 2.38 min elapsed,
# 20,000 items handled, 2.59 min elapsed,
# 21,000 items handled, 2.73 min elapsed,
# 22,000 items handled, 2.83 min elapsed,
# 23,000 items handled, 2.96 min elapsed,
# 24,000 items handled, 3.04 min elapsed,
# 25,000 items handled, 3.13 min elapsed,
# 26,000 items handled, 3.24 min elapsed,
# 27,000 items handled, 3.38 min elapsed,
# 28,000 items handled, 3.51 min elapsed,
# 29,000 items handled, 3.58 min elapsed,
# 30,000 items handled, 3.66 min elapsed,
# 31,000 items handled, 3.75 min elapsed,
# 32,000 items handled, 3.81 min elapsed,
# 33,000 items handled, 3.89 min elapsed,
# 34,000 items handled, 3.99 min elapsed,
# 35,000 items handled, 4.05 min elapsed,
# 36,000 items handled, 4.17 min elapsed,
# 37,000 items handled, 4.29 min elapsed,
# 38,000 items handled, 4.43 min elapsed,
# 39,000 items handled, 4.55 min elapsed,
# 40,000 items handled, 4.68 min elapsed,
# 41,000 items handled, 4.83 min elapsed,
# 42,000 items handled, 4.94 min elapsed,
# 43,000 items handled, 5.02 min elapsed,
# 44,000 items handled, 5.10 min elapsed,
# 45,000 items handled, 5.22 min elapsed,
# 46,000 items handled, 5.37 min elapsed,
# 47,000 items handled, 5.49 min elapsed,
# 48,000 items handled, 5.65 min elapsed,
# 49,000 items handled, 5.75 min elapsed,
# 50,000 items handled, 5.84 min elapsed,
# 51,000 items handled, 6.00 min elapsed,
# 52,000 items handled, 6.11 min elapsed,
# 53,000 items handled, 6.21 min elapsed,
# 54,000 items handled, 6.35 min elapsed,
# 55,000 items handled, 6.48 min elapsed,
# 56,000 items handled, 6.57 min elapsed,
# 57,000 items handled, 6.67 min elapsed,
# 58,000 items handled, 6.81 min elapsed,
# 59,000 items handled, 6.93 min elapsed,
# 60,000 items handled, 7.02 min elapsed,
# 61,000 items handled, 7.15 min elapsed,
# 62,000 items handled, 7.24 min elapsed,
# 63,000 items handled, 7.40 min elapsed,
# 64,000 items handled, 7.54 min elapsed,
# 65,000 items handled, 7.76 min elapsed,
# 66,000 items handled, 7.89 min elapsed,
# 67,000 items handled, 7.98 min elapsed,
# 68,000 items handled, 8.11 min elapsed,
# 69,000 items handled, 8.19 min elapsed,
# 70,000 items handled, 8.26 min elapsed,
# 71,000 items handled, 8.38 min elapsed,
# 72,000 items handled, 8.48 min elapsed,
# 73,000 items handled, 8.62 min elapsed,
# 74,000 items handled, 8.73 min elapsed,
# 75,000 items handled, 8.89 min elapsed,
# 76,000 items handled, 9.02 min elapsed,
# 77,000 items handled, 9.15 min elapsed,
# 78,000 items handled, 9.31 min elapsed,
# 79,000 items handled, 9.46 min elapsed,
# 80,000 items handled, 9.59 min elapsed,
# 81,000 items handled, 9.71 min elapsed,
# 82,000 items handled, 9.81 min elapsed,
# 83,000 items handled, 9.98 min elapsed,
# 84,000 items handled, 10.14 min elapsed,
# 85,000 items handled, 10.29 min elapsed,
# 86,000 items handled, 10.45 min elapsed,
# 87,000 items handled, 10.61 min elapsed,
# 88,000 items handled, 10.86 min elapsed,
# 89,000 items handled, 11.01 min elapsed,
# 90,000 items handled, 11.16 min elapsed,
# 91,000 items handled, 11.28 min elapsed,
# 92,000 items handled, 11.43 min elapsed,
# 93,000 items handled, 11.58 min elapsed,
# 94,000 items handled, 11.69 min elapsed,
# 95,000 items handled, 11.87 min elapsed,
# 96,000 items handled, 12.03 min elapsed,
# 97,000 items handled, 12.15 min elapsed,
# 98,000 items handled, 12.25 min elapsed,
# 99,000 items handled, 12.35 min elapsed,
# 100,000 items handled, 12.50 min elapsed,
# 101,000 items handled, 12.64 min elapsed,
# 102,000 items handled, 12.81 min elapsed,
# 103,000 items handled, 12.93 min elapsed,
# 104,000 items handled, 13.04 min elapsed,
# 105,000 items handled, 13.16 min elapsed,
# 106,000 items handled, 13.28 min elapsed,
# 107,000 items handled, 13.40 min elapsed,
# 108,000 items handled, 13.53 min elapsed,
# 109,000 items handled, 13.65 min elapsed,
# 110,000 items handled, 13.71 min elapsed,
# 111,000 items handled, 13.82 min elapsed,
# 112,000 items handled, 13.89 min elapsed,
# 113,000 items handled, 14.03 min elapsed,
# 114,000 items handled, 14.14 min elapsed,
# 115,000 items handled, 14.25 min elapsed,
# 116,000 items handled, 14.37 min elapsed,
# 117,000 items handled, 14.51 min elapsed,
# 118,000 items handled, 14.70 min elapsed,
# 119,000 items handled, 14.81 min elapsed,
# 120,000 items handled, 14.92 min elapsed,
# 121,000 items handled, 15.03 min elapsed,
# 122,000 items handled, 15.14 min elapsed,
# 123,000 items handled, 15.25 min elapsed,
# 124,000 items handled, 15.35 min elapsed,
# 125,000 items handled, 15.46 min elapsed,
# 126,000 items handled, 15.65 min elapsed,
# 127,000 items handled, 15.77 min elapsed,
# 128,000 items handled, 15.85 min elapsed,
# 129,000 items handled, 15.99 min elapsed,
# 130,000 items handled, 16.10 min elapsed,
# 131,000 items handled, 16.20 min elapsed,
# 132,000 items handled, 16.34 min elapsed,
# 133,000 items handled, 16.53 min elapsed,
# 134,000 items handled, 16.63 min elapsed,
# 135,000 items handled, 16.81 min elapsed,
# 136,000 items handled, 16.95 min elapsed,
# 137,000 items handled, 17.05 min elapsed,
# 138,000 items handled, 17.20 min elapsed,
# 139,000 items handled, 17.29 min elapsed,
# 140,000 items handled, 17.41 min elapsed,
# 141,000 items handled, 17.51 min elapsed,
# 142,000 items handled, 17.61 min elapsed,
# 143,000 items handled, 17.69 min elapsed,
# 144,000 items handled, 17.86 min elapsed,
# 145,000 items handled, 17.95 min elapsed,
# 146,000 items handled, 18.02 min elapsed,
# 147,000 items handled, 18.10 min elapsed,
# 148,000 items handled, 18.19 min elapsed,
# 149,000 items handled, 18.30 min elapsed,
# 150,000 items handled, 18.42 min elapsed,
# 151,000 items handled, 18.55 min elapsed,
# 152,000 items handled, 18.68 min elapsed,
# 153,000 items handled, 18.77 min elapsed,
# 154,000 items handled, 18.89 min elapsed,
# 155,000 items handled, 18.94 min elapsed,
# 156,000 items handled, 18.96 min elapsed,
# 157,000 items handled, 18.99 min elapsed,
# 158,000 items handled, 19.06 min elapsed,
# 159,000 items handled, 19.16 min elapsed,
# 160,000 items handled, 19.26 min elapsed,
# 161,000 items handled, 19.38 min elapsed,
# 162,000 items handled, 19.45 min elapsed,
# 163,000 items handled, 19.57 min elapsed,
# 164,000 items handled, 19.68 min elapsed,
# 165,000 items handled, 19.80 min elapsed,
# 166,000 items handled, 19.87 min elapsed,
# 167,000 items handled, 19.99 min elapsed,
# 168,000 items handled, 20.11 min elapsed,
# 169,000 items handled, 20.24 min elapsed,
# 170,000 items handled, 20.35 min elapsed,
# 171,000 items handled, 20.47 min elapsed,
# 172,000 items handled, 20.52 min elapsed,
# 173,000 items handled, 20.69 min elapsed,
# 174,000 items handled, 20.79 min elapsed,
# 175,000 items handled, 20.90 min elapsed,
# 176,000 items handled, 21.00 min elapsed,
# 177,000 items handled, 21.10 min elapsed,
# 178,000 items handled, 21.20 min elapsed,
# 179,000 items handled, 21.32 min elapsed,
# 180,000 items handled, 21.41 min elapsed,
# 181,000 items handled, 21.50 min elapsed,
# 182,000 items handled, 21.57 min elapsed,
# 183,000 items handled, 21.66 min elapsed,
# 184,000 items handled, 21.74 min elapsed,
# 185,000 items handled, 21.85 min elapsed,
# 186,000 items handled, 21.93 min elapsed,
# 187,000 items handled, 22.04 min elapsed,
# 188,000 items handled, 22.11 min elapsed,
# 189,000 items handled, 22.21 min elapsed,
# 190,000 items handled, 22.32 min elapsed,
# 191,000 items handled, 22.42 min elapsed,
# 192,000 items handled, 22.49 min elapsed,
# 193,000 items handled, 22.58 min elapsed,
# 194,000 items handled, 22.67 min elapsed,
# 195,000 items handled, 22.75 min elapsed,
# 196,000 items handled, 22.82 min elapsed,
# 197,000 items handled, 22.90 min elapsed,
# 198,000 items handled, 22.98 min elapsed,
# 199,000 items handled, 23.10 min elapsed,
# 200,000 items handled, 23.25 min elapsed,
# 201,000 items handled, 23.32 min elapsed,
# 202,000 items handled, 23.42 min elapsed,
# 203,000 items handled, 23.53 min elapsed,
# 204,000 items handled, 23.63 min elapsed,
# 205,000 items handled, 23.72 min elapsed,
# 206,000 items handled, 23.82 min elapsed,
# 207,000 items handled, 23.92 min elapsed,
# 208,000 items handled, 24.12 min elapsed,
# 209,000 items handled, 24.22 min elapsed,
# 210,000 items handled, 24.31 min elapsed,
# 211,000 items handled, 24.41 min elapsed,
# 212,000 items handled, 24.50 min elapsed,
# 213,000 items handled, 24.57 min elapsed,
# 214,000 items handled, 24.67 min elapsed,
# 215,000 items handled, 24.75 min elapsed,
# 216,000 items handled, 24.90 min elapsed,
# 217,000 items handled, 24.99 min elapsed,
# 218,000 items handled, 25.06 min elapsed,
# 219,000 items handled, 25.11 min elapsed,
# 220,000 items handled, 25.26 min elapsed,
# 221,000 items handled, 25.41 min elapsed,
# 222,000 items handled, 25.48 min elapsed,
# 223,000 items handled, 25.59 min elapsed,
# 224,000 items handled, 25.68 min elapsed,
# 225,000 items handled, 25.77 min elapsed,
# 226,000 items handled, 25.84 min elapsed,
# 227,000 items handled, 25.94 min elapsed,
# 228,000 items handled, 26.03 min elapsed,
# 229,000 items handled, 26.15 min elapsed,
# 230,000 items handled, 26.26 min elapsed,
# 231,000 items handled, 26.36 min elapsed,
# 232,000 items handled, 26.45 min elapsed,
# 233,000 items handled, 26.54 min elapsed,
# 234,000 items handled, 26.61 min elapsed,
# 235,000 items handled, 26.69 min elapsed,
# 236,000 items handled, 26.79 min elapsed,
# 237,000 items handled, 26.88 min elapsed,
# 238,000 items handled, 26.97 min elapsed,
# 239,000 items handled, 27.06 min elapsed,
# 240,000 items handled, 27.17 min elapsed,
# 241,000 items handled, 27.26 min elapsed,
# 242,000 items handled, 27.36 min elapsed,
# 243,000 items handled, 27.42 min elapsed,
# 244,000 items handled, 27.50 min elapsed,
# 245,000 items handled, 27.60 min elapsed,
# 246,000 items handled, 27.71 min elapsed,
# 247,000 items handled, 27.82 min elapsed,
# 248,000 items handled, 27.96 min elapsed,
# 249,000 items handled, 28.09 min elapsed,
# 250,000 items handled, 28.21 min elapsed,
# 251,000 items handled, 28.33 min elapsed,
# 252,000 items handled, 28.50 min elapsed,
# 253,000 items handled, 28.63 min elapsed,
# 254,000 items handled, 28.73 min elapsed,
# 255,000 items handled, 28.80 min elapsed,
# 256,000 items handled, 28.91 min elapsed,
# 257,000 items handled, 28.99 min elapsed,
# 258,000 items handled, 29.08 min elapsed,
# 259,000 items handled, 29.21 min elapsed,
# 260,000 items handled, 29.34 min elapsed,
# 261,000 items handled, 29.44 min elapsed,
# 262,000 items handled, 29.58 min elapsed,
# 263,000 items handled, 29.68 min elapsed,
# 264,000 items handled, 29.77 min elapsed,
# 265,000 items handled, 29.86 min elapsed,
# 266,000 items handled, 29.93 min elapsed,
# 267,000 items handled, 30.11 min elapsed,
# 268,000 items handled, 30.25 min elapsed,
# 269,000 items handled, 30.33 min elapsed,
# 270,000 items handled, 30.43 min elapsed,
# 271,000 items handled, 30.55 min elapsed,
# 272,000 items handled, 30.65 min elapsed,
# 273,000 items handled, 30.76 min elapsed,
# 274,000 items handled, 30.89 min elapsed,
# 275,000 items handled, 30.99 min elapsed,
# 276,000 items handled, 31.09 min elapsed,
# 277,000 items handled, 31.19 min elapsed,
# 278,000 items handled, 31.31 min elapsed,
# 279,000 items handled, 31.43 min elapsed,
# 280,000 items handled, 31.50 min elapsed,
# 281,000 items handled, 31.60 min elapsed,
# 282,000 items handled, 31.70 min elapsed,
# 283,000 items handled, 31.79 min elapsed,
# 284,000 items handled, 31.90 min elapsed,
# 285,000 items handled, 32.00 min elapsed,
# 286,000 items handled, 32.09 min elapsed,
# 287,000 items handled, 32.23 min elapsed,
# 288,000 items handled, 32.33 min elapsed,
# 289,000 items handled, 32.45 min elapsed,
# 290,000 items handled, 32.54 min elapsed,
# 291,000 items handled, 32.64 min elapsed,
# 292,000 items handled, 32.74 min elapsed,
# 293,000 items handled, 32.84 min elapsed,
# 294,000 items handled, 32.92 min elapsed,
# 295,000 items handled, 33.04 min elapsed,
# 296,000 items handled, 33.14 min elapsed,
# 297,000 items handled, 33.21 min elapsed,
# 298,000 items handled, 33.32 min elapsed,
# 299,000 items handled, 33.42 min elapsed,
# 300,000 items handled, 33.53 min elapsed,
# 301,000 items handled, 33.63 min elapsed,
# 302,000 items handled, 33.72 min elapsed,
# 303,000 items handled, 33.81 min elapsed,
# 304,000 items handled, 33.92 min elapsed,
# 305,000 items handled, 34.00 min elapsed,
# 306,000 items handled, 34.11 min elapsed,
# 307,000 items handled, 34.20 min elapsed,
# 308,000 items handled, 34.35 min elapsed,
# 309,000 items handled, 34.45 min elapsed,
# 310,000 items handled, 34.56 min elapsed,
# 311,000 items handled, 34.69 min elapsed,
# 312,000 items handled, 34.75 min elapsed,
# 313,000 items handled, 34.85 min elapsed,
# 314,000 items handled, 34.95 min elapsed,
# 315,000 items handled, 35.06 min elapsed,
# 316,000 items handled, 35.20 min elapsed,
# 317,000 items handled, 35.32 min elapsed,
# 318,000 items handled, 35.42 min elapsed,
# 319,000 items handled, 35.50 min elapsed,
# 320,000 items handled, 35.61 min elapsed,
# 321,000 items handled, 35.73 min elapsed,
# 322,000 items handled, 35.89 min elapsed,
# 323,000 items handled, 35.97 min elapsed,
# 324,000 items handled, 36.05 min elapsed,
# 325,000 items handled, 36.12 min elapsed,
# 326,000 items handled, 36.22 min elapsed,
# 327,000 items handled, 36.35 min elapsed,
# 328,000 items handled, 36.45 min elapsed,
# 329,000 items handled, 36.55 min elapsed,
# 330,000 items handled, 36.66 min elapsed,
# 331,000 items handled, 36.81 min elapsed,
# 332,000 items handled, 36.90 min elapsed,
# 333,000 items handled, 37.00 min elapsed,
# 334,000 items handled, 37.10 min elapsed,
# 335,000 items handled, 37.21 min elapsed,
# 336,000 items handled, 37.32 min elapsed,
# 337,000 items handled, 37.42 min elapsed,
# 338,000 items handled, 37.52 min elapsed,
# 339,000 items handled, 37.62 min elapsed,
# 340,000 items handled, 37.73 min elapsed,
# 341,000 items handled, 37.86 min elapsed,
# 342,000 items handled, 37.97 min elapsed,
# 343,000 items handled, 38.05 min elapsed,
# 344,000 items handled, 38.18 min elapsed,
# 345,000 items handled, 38.27 min elapsed,
# 346,000 items handled, 38.34 min elapsed,
# 347,000 items handled, 38.43 min elapsed,
# 348,000 items handled, 38.56 min elapsed,
# 349,000 items handled, 38.68 min elapsed,
# 350,000 items handled, 38.80 min elapsed,
# 351,000 items handled, 38.91 min elapsed,
# 352,000 items handled, 39.02 min elapsed,
# 353,000 items handled, 39.12 min elapsed,
# 354,000 items handled, 39.24 min elapsed,
# 355,000 items handled, 39.31 min elapsed,
# 356,000 items handled, 39.38 min elapsed,
# 357,000 items handled, 39.47 min elapsed,
# 358,000 items handled, 39.58 min elapsed,
# 359,000 items handled, 39.67 min elapsed,
# 360,000 items handled, 39.75 min elapsed,
# 361,000 items handled, 39.82 min elapsed,
# 362,000 items handled, 39.91 min elapsed,
# 363,000 items handled, 40.05 min elapsed,
# 364,000 items handled, 40.18 min elapsed,
# 365,000 items handled, 40.25 min elapsed,
# 366,000 items handled, 40.36 min elapsed,
# 367,000 items handled, 40.45 min elapsed,
# 368,000 items handled, 40.54 min elapsed,
# 369,000 items handled, 40.64 min elapsed,
# 370,000 items handled, 40.71 min elapsed,
# 371,000 items handled, 40.84 min elapsed,
# 372,000 items handled, 40.94 min elapsed,
# 373,000 items handled, 41.04 min elapsed,
# 374,000 items handled, 41.17 min elapsed,
# 375,000 items handled, 41.28 min elapsed,
# 376,000 items handled, 41.37 min elapsed,
# 377,000 items handled, 41.50 min elapsed,
# 378,000 items handled, 41.60 min elapsed,
# 379,000 items handled, 41.71 min elapsed,
# 380,000 items handled, 41.83 min elapsed,
# 381,000 items handled, 41.92 min elapsed,
# 382,000 items handled, 42.00 min elapsed,
# 383,000 items handled, 42.13 min elapsed,
# 384,000 items handled, 42.24 min elapsed,
# 385,000 items handled, 42.33 min elapsed,
# 386,000 items handled, 42.45 min elapsed,
# 387,000 items handled, 42.55 min elapsed,
# 388,000 items handled, 42.66 min elapsed,
# 389,000 items handled, 42.77 min elapsed,
# 390,000 items handled, 42.90 min elapsed,
# 391,000 items handled, 43.07 min elapsed,
# 392,000 items handled, 43.18 min elapsed,
# 393,000 items handled, 43.27 min elapsed,
# 394,000 items handled, 43.41 min elapsed,
# 395,000 items handled, 43.57 min elapsed,
# 396,000 items handled, 43.67 min elapsed,
# 397,000 items handled, 43.80 min elapsed,
# 398,000 items handled, 43.91 min elapsed,
# 399,000 items handled, 44.03 min elapsed,
# 400,000 items handled, 44.16 min elapsed,
# 401,000 items handled, 44.27 min elapsed,
# 402,000 items handled, 44.37 min elapsed,
# 403,000 items handled, 44.47 min elapsed,
# 404,000 items handled, 44.55 min elapsed,
# 405,000 items handled, 44.62 min elapsed,
# 406,000 items handled, 44.71 min elapsed,
# 407,000 items handled, 44.81 min elapsed,
# 408,000 items handled, 44.95 min elapsed,
# 409,000 items handled, 45.06 min elapsed,
# 410,000 items handled, 45.21 min elapsed,
# 411,000 items handled, 45.34 min elapsed,
# 412,000 items handled, 45.46 min elapsed,
# 413,000 items handled, 45.57 min elapsed,
# 414,000 items handled, 45.67 min elapsed,
# 415,000 items handled, 45.77 min elapsed,
# 416,000 items handled, 45.86 min elapsed,
# 417,000 items handled, 45.97 min elapsed,
# 418,000 items handled, 46.07 min elapsed,
# 419,000 items handled, 46.17 min elapsed,
# 420,000 items handled, 46.27 min elapsed,
# 421,000 items handled, 46.37 min elapsed,
# 422,000 items handled, 46.51 min elapsed,
# 423,000 items handled, 46.65 min elapsed,
# 424,000 items handled, 46.78 min elapsed,
# 425,000 items handled, 46.90 min elapsed,
# 426,000 items handled, 47.05 min elapsed,
# 427,000 items handled, 47.13 min elapsed,
# 428,000 items handled, 47.22 min elapsed,
# 429,000 items handled, 47.29 min elapsed,
# 430,000 items handled, 47.39 min elapsed,
# 431,000 items handled, 47.51 min elapsed,
# 432,000 items handled, 47.58 min elapsed,
# 433,000 items handled, 47.72 min elapsed,
# 434,000 items handled, 47.88 min elapsed,
# 435,000 items handled, 48.00 min elapsed,
# 436,000 items handled, 48.11 min elapsed,
# 437,000 items handled, 48.23 min elapsed,
# 438,000 items handled, 48.34 min elapsed,
# 439,000 items handled, 48.43 min elapsed,
# 440,000 items handled, 48.54 min elapsed,
# 441,000 items handled, 48.68 min elapsed,
# 442,000 items handled, 48.80 min elapsed,
# 443,000 items handled, 48.94 min elapsed,
# 444,000 items handled, 49.07 min elapsed,
# 445,000 items handled, 49.22 min elapsed,
# 446,000 items handled, 49.37 min elapsed,
# 447,000 items handled, 49.47 min elapsed,
# 448,000 items handled, 49.57 min elapsed,
# 449,000 items handled, 49.69 min elapsed,
# 450,000 items handled, 49.79 min elapsed,
# 451,000 items handled, 49.92 min elapsed,
# 452,000 items handled, 50.07 min elapsed,
# 453,000 items handled, 50.17 min elapsed,
# 454,000 items handled, 50.29 min elapsed,
# 455,000 items handled, 50.42 min elapsed,
# 456,000 items handled, 50.54 min elapsed,
# 457,000 items handled, 50.67 min elapsed,
# 458,000 items handled, 50.81 min elapsed,
# 459,000 items handled, 50.91 min elapsed,
# 460,000 items handled, 51.04 min elapsed,
# 461,000 items handled, 51.16 min elapsed,
# 462,000 items handled, 51.26 min elapsed,
# Cleaner finished at: Sun Dec  4 21:26:59 2022
# 51.39 min elapsed.

# %%
pd.read_csv("forecast_final.csv")
# Out:
#             id                               stop_id  \
# 0            8  a67e06ee-4fe7-4ee6-bc01-dc428924b4a1
# 1            9  a67e06ee-4fe7-4ee6-bc01-dc428924b4a1
# 2          147  f76c2410-374c-4f0b-b3e4-45523665957f
# 3          213  8431e36b-9716-4794-b349-13e69c994324
# 4          217  c3b241da-0c88-46d4-a242-2c1a51a30f8c
# ...        ...                                   ...
# 493497  999986  be06527b-df8f-489c-b2a3-323c8de88bac
# 493498  999987  be06527b-df8f-489c-b2a3-323c8de88bac
# 493499  999993  0263b458-56b0-445a-80b6-6b2291ff4255
# 493500  999996  0263b458-56b0-445a-80b6-6b2291ff4255
# 493501  999999  0263b458-56b0-445a-80b6-6b2291ff4255
#
#                                route_path_id  forecast_time  byTelemetry  \
# 0       05367e1b-150e-44ab-8c88-ef0cc3d363a7     1644620883            1
# 1       05367e1b-150e-44ab-8c88-ef0cc3d363a7     1644622528            1
# 2       1401248b-5212-4b51-8c7e-b651dc59bd5f     1644621156            1
# 3       1401248b-5212-4b51-8c7e-b651dc59bd5f     1644622027            1
# 4       1401248b-5212-4b51-8c7e-b651dc59bd5f     1644622094            1
# ...                                      ...            ...          ...
# 493497  d5a4ba23-7a6a-4fec-af0d-eabeee541eb8     1644668624            1
# 493498  0ed01412-18d3-4fdc-b3ca-9125b19916c9     1644666654            1
# 493499  fa38fbf9-18f6-4be0-92ac-bc1e49d93951     1644665639            1
# 493500  d246bbfd-46dc-4624-9a40-0b83840c7e28     1644665886            1
# 493501  0a272c86-095d-4c8b-afb6-27fc13c71fa4     1644665932            1
#
#            tmId                           routePathId  request_time
# 0       1445173  d819c2bc-43a4-4f02-b3e9-28a6f291e9d4    1644620502
# 1       1445146  d819c2bc-43a4-4f02-b3e9-28a6f291e9d4    1644620502
# 2       1593476  68406a24-07ce-4022-8bea-4911e6f8d8d8    1644620940
# 3       1593476  68406a24-07ce-4022-8bea-4911e6f8d8d8    1644620940
# 4       1593476  68406a24-07ce-4022-8bea-4911e6f8d8d8    1644620940
# ...         ...                                   ...           ...
# 493497    38448  880dbcbc-5c8b-451b-a07a-3e5378ba6cb4    1644665572
# 493498    38728  839cc56b-1e24-48c2-ac1c-3ae3b655629c    1644665572
# 493499  1304142  3da63d7f-8289-4dc1-ad23-cb8da9b6c8b6    1644665572
# 493500  1151872  05f24588-7c54-4504-9ec6-2afeb5c288f6    1644665572
# 493501  1301116  c99e345f-d114-464c-9c39-7f56541d16fc    1644665572
#
# [493502 rows x 8 columns]
